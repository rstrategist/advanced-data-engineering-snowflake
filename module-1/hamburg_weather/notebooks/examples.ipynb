# %%
from dotenv import load_dotenv
import os

load_dotenv()  # reads from .env

account = os.getenv("SNOWFLAKE_ACCOUNT")
user = os.getenv("SNOWFLAKE_USER")
password = os.getenv("SNOWFLAKE_PASSWORD")

# %%
from datetime import timedelta

from snowflake.snowpark import Session
from snowflake.snowpark.functions import col
from snowflake.core import Root, CreateMode
from snowflake.core.database import Database
from snowflake.core.schema import Schema
from snowflake.core.stage import Stage
from snowflake.core.table import Table, TableColumn, PrimaryKey
from snowflake.core.task import StoredProcedureCall, Task
from snowflake.core.task.dagv1 import DAGOperation, DAG, DAGTask
from snowflake.core.warehouse import Warehouse

# %%
session = Session.builder.config("connection_name", "default").create()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 session = Session.builder.config("connection_name", "default").create()
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\snowpark\session.py:519, in Session.SessionBuilder.create(self)
#     517     _add_session(session)
#     518 else:
# --> 519     session = self._create_internal(self._options.get("connection"))
#     521 if self._app_name:
#     522     if self._format_json:
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\snowpark\session.py:561, in Session.SessionBuilder._create_internal(self, conn)
#     558 if "paramstyle" not in self._options:
#     559     self._options["paramstyle"] = "qmark"
#     560 new_session = Session(
# --> 561     ServerConnection({}, conn) if conn else ServerConnection(self._options),
#     562     self._options,
#     563 )
#     565 if "password" in self._options:
#     566     self._options["password"] = None
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\snowpark\_internal\server_connection.py:168, in ServerConnection.__init__(self, options, conn)
#     166 self._lower_case_parameters = {k.lower(): v for k, v in options.items()}
#     167 self._add_application_parameters()
# --> 168 self._conn = conn if conn else connect(**self._lower_case_parameters)
#     169 self.max_string_size = DEFAULT_STRING_SIZE
#     170 if self._conn._session_parameters:
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\connector\__init__.py:66, in Connect(**kwargs)
#      64 @wraps(SnowflakeConnection.__init__)
#      65 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 66     return SnowflakeConnection(**kwargs)
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\connector\connection.py:588, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     586     kwargs = _get_default_connection_params()
#     587 self.__set_error_attributes()
# --> 588 self.connect(**kwargs)
#     589 self._telemetry = TelemetryClient(self._rest)
#     590 self.expired = False
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\connector\connection.py:972, in SnowflakeConnection.connect(self, **kwargs)
#     970             raise Exception(str(exceptions_dict))
#     971 else:
# --> 972     self.__open_connection()
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\connector\connection.py:1371, in SnowflakeConnection.__open_connection(self)
#    1363 else:
#    1364     # okta URL, e.g., https://<account>.okta.com/
#    1365     self.auth_class = AuthByOkta(
#    1366         application=self.application,
#    1367         timeout=self.login_timeout,
#    1368         backoff_generator=self._backoff_generator,
#    1369     )
# -> 1371 self.authenticate_with_retry(self.auth_class)
#    1373 self._password = None  # ensure password won't persist
#    1374 self.auth_class.reset_secrets()
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\connector\connection.py:1704, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1701 def authenticate_with_retry(self, auth_instance) -> None:
#    1702     # make some changes if needed before real __authenticate
#    1703     try:
# -> 1704         self._authenticate(auth_instance)
#    1705     except ReauthenticationRequest as ex:
#    1706         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1707         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\connector\connection.py:1736, in SnowflakeConnection._authenticate(self, auth_instance)
#    1734 auth_instance._retry_ctx.set_start_time()
#    1735 try:
# -> 1736     auth.authenticate(
#    1737         auth_instance=auth_instance,
#    1738         account=self.account,
#    1739         user=self.user,
#    1740         database=self.database,
#    1741         schema=self.schema,
#    1742         warehouse=self.warehouse,
#    1743         role=self.role,
#    1744         passcode=self._passcode,
#    1745         passcode_in_password=self._passcode_in_password,
#    1746         mfa_callback=self._mfa_callback,
#    1747         password_callback=self._password_callback,
#    1748         session_parameters=self._session_parameters,
#    1749     )
#    1750 except OperationalError as e:
#    1751     logger.debug(
#    1752         "Operational Error raised at authentication"
#    1753         f"for authenticator: {type(auth_instance).__name__}"
#    1754     )
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\connector\auth\_auth.py:401, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     397     if isinstance(auth_instance, AuthByUsrPwdMfa):
#     398         self._delete_temporary_credential(
#     399             self._rest._host, user, TokenType.MFA_TOKEN
#     400         )
# --> 401     Error.errorhandler_wrapper(
#     402         self._rest._connection,
#     403         None,
#     404         DatabaseError,
#     405         {
#     406             "msg": (
#     407                 "Failed to connect to DB: {host}:{port}. " "{message}"
#     408             ).format(
#     409                 host=self._rest._host,
#     410                 port=self._rest._port,
#     411                 message=ret["message"],
#     412             ),
#     413             "errno": ER_FAILED_TO_CONNECT_TO_DB,
#     414             "sqlstate": SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     415         },
#     416     )
#     417 else:
#     418     logger.debug(
#     419         "token = %s",
#     420         (
#    (...)    424         ),
#     425     )
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\connector\errors.py:286, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     263 @staticmethod
#     264 def errorhandler_wrapper(
#     265     connection: SnowflakeConnection | None,
#    (...)    268     error_value: dict[str, Any],
#     269 ) -> None:
#     270     """Error handler wrapper that calls the errorhandler method.
#     271
#     272     Args:
#    (...)    283         exception to the first handler in that order.
#     284     """
# --> 286     handed_over = Error.hand_to_other_handler(
#     287         connection,
#     288         cursor,
#     289         error_class,
#     290         error_value,
#     291     )
#     292     if not handed_over:
#     293         raise Error.errorhandler_make_exception(
#     294             error_class,
#     295             error_value,
#     296         )
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\connector\errors.py:344, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     342     return True
#     343 elif connection is not None:
# --> 344     connection.errorhandler(connection, cursor, error_class, error_value)
#     345     return True
#     346 return False
#
# File c:\GitHub\advanced-data-engineering-snowflake\~\.venv\Lib\site-packages\snowflake\connector\errors.py:217, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     215 errno = error_value.get("errno")
#     216 done_format_msg = error_value.get("done_format_msg")
# --> 217 raise error_class(
#     218     msg=error_value.get("msg"),
#     219     errno=None if errno is None else int(errno),
#     220     sqlstate=error_value.get("sqlstate"),
#     221     sfqid=error_value.get("sfqid"),
#     222     query=error_value.get("query"),
#     223     done_format_msg=(
#     224         None if done_format_msg is None else bool(done_format_msg)
#     225     ),
#     226     connection=connection,
#     227     cursor=cursor,
#     228 )
#
# DatabaseError: 250001 (08001): Failed to connect to DB: XFRSSUR-GQB31557.snowflakecomputing.com:443. Incorrect username or password was specified.

# %%
root = Root(session)
